# %%
questions = [
    "Which word describes you more often than the other? \n (a) Confident \n (b) Helpful",
    "Which word describes you more often than the other? \n (a) Self-reliant \n (b) Understanding",
    "Which word describes you more often than the other? \n (a) Fast-paced \n (b) Easy-going",
    "Which word describes you more often than the other? \n (a) Independent \n (b) Team Player",
    "Which word describes you more often than the other? \n (a) Decisive \n (b) Diplomatic",
    "Which word describes you more often than the other? \n (a) Assertive \n (b) Non-confrontational",
    "Which word describes you more often than the other? \n (a) Competitive \n (b) Cooperative",
    "Which word describes you more often than the other? \n (a) Strong-willed \n (b) Tolerant",
    "Which word describes you more often than the other? \n (a) Leader \n (b) Loyal",
    "Which word describes you more often than the other? \n (a) Goal-centered \n (b) People-centered",
    "Which word describes you more often than the other? \n (a) Initiator \n (b) Listener",
    "Which word describes you more often than the other? \n (a) Determined \n (b) Unselfish",
    "Which word describes you more often than the other? \n (a) Straightforward \n (b) Patient",
    "Which word describes you more often than the other? \n (a) Results-focused \n (b) Relationship-focused",
    "Which word describes you more often than the other? \n (a) Hardworking \n (b) Friendly",
    "Which word describes you more often than the other? \n (a) In-charge \n (b) Generous",
    "Which word describes you more often than the other? \n (a) Task-oriented \n (b) Peace-oriented",
    "Which word describes you more often than the other? \n (a) Authoritative \n (b) Considerate",
    "Which word describes you more often than the other? \n (a) Bold \n (b) Supportive",
    "Which word describes you more often than the other? \n (a) Productive \n (b) Faithful",
    "Which word describes you more often than the other? \n (a) Self-starter \n (b) Volunteer",
    "Which word describes you more often than the other? \n (a) Autocratic \n (b) Accommodating",
    "Which word describes you more often than the other? \n (a) Directive \n (b) Sociable",
    "Which word describes you more often than the other? \n (a) Opinionated \n (b) Sensitive",
    "Which word describes you more often than the other? \n (a) Challenger \n (b) Mediator",
    "Which word describes you more often than the other? \n (a) Doer \n (b) Communicator",
    "Which word describes you more often than the other? \n (a) Deadline-driven \n (b) Values-driven",
    "Which word describes you more often than the other? \n (a) Tough \n (b) Appreciative",
    "Which word describes you more often than the other? \n (a) Driver \n (b) Pleaser",
    "Which word describes you more often than the other? \n (a) Achiever \n (b) Caregiver",
    "Which word describes you more often than the other? \n (c) Organized \n (d) Creative",
    "Which word describes you more often than the other? \n (c) Structured \n (d) Flexible",
    "Which word describes you more often than the other? \n (c) Quality-centered \n (d) Idea-centered",
    "Which word describes you more often than the other? \n (c) Cultured \n (d) Enthusiastic",
    "Which word describes you more often than the other? \n (c) Logical \n (d) Visionary",
    "Which word describes you more often than the other? \n (c) Reserved \n (d) Innovative",
    "Which word describes you more often than the other? \n (c) Planner \n (d) Spontaneous",
    "Which word describes you more often than the other? \n (c) Focused \n (d) Resourceful",
    "Which word describes you more often than the other? \n (c) Perfectionist \n (d) Free-spirited",
    "Which word describes you more often than the other? \n (c) Traditional \n (d) Risk-taker",
    "Which word describes you more often than the other? \n (c) Factual \n (d) Fun-loving",
    "Which word describes you more often than the other? \n (c) Analytical \n (d) Cheerful",
    "Which word describes you more often than the other? \n (c) Consistent \n (d) Versatile",
    "Which word describes you more often than the other? \n (c) Serious \n (d) Humorous",
    "Which word describes you more often than the other? \n (c) Efficient \n (d) Dreamer",
    "Which word describes you more often than the other? \n (c) Punctual \n (d) Daring",
    "Which word describes you more often than the other? \n (c) Reliable \n (d) Delegator",
    "Which word describes you more often than the other? \n (c) Industrious \n (d) Improvising",
    "Which word describes you more often than the other? \n (c) Persistent \n (d) Imaginative",
    "Which word describes you more often than the other? \n (c) Cautious \n (d) Open-minded",
    "Which word describes you more often than the other? \n (c) Finisher \n (d) Motivator",
    "Which word describes you more often than the other? \n (c) Rule-follower \n (d) Option-provider",
    "Which word describes you more often than the other? \n (c) Systematic \n (d) Carefree",
    "Which word describes you more often than the other? \n (c) Precise \n (d) Inventive",
    "Which word describes you more often than the other? \n (c) Standard-setter \n (d) Coordinator",
    "Which word describes you more often than the other? \n (c) Persuasive \n (d) Adventurous",
    "Which word describes you more often than the other? \n (c) Protocol-focused \n (d) Methods-focused",
    "Which word describes you more often than the other? \n (c) Accurate \n (d) Adaptable",
    "Which word describes you more often than the other? \n (c) Double-checker \n (d) Wheeler-dealer",
    "Which word describes you more often than the other? \n (c) Record-keeper \n (d) Trend-setter"   
]
